# %% [markdown]
# # Leveling Modeling Overview
#
# 이 노트북은 레벨링 시뮬레이션 summary를 사람이 검토하기 위한 개요용 노트북이다.
#
# 현재 기준은 학습 모델 적용이 아니라 시뮬레이션과 휴리스틱 진단 라벨이다. 현재 feature table과 모델 metric은 실제 ML 전환 완료가 아니라 스캐폴딩이다. 실제 ML 전환 시에는 pre-outcome feature와 추천 target을 다시 설계한 뒤 `tools/leveling/build_feature_table.py`와 `tools/leveling/train_leveling_model.py`를 확장한다.

# %%
from pathlib import Path
import pandas as pd

feature_path = Path('../data/features/leveling_feature_table.csv')
feature_path.exists()

# %%
if feature_path.exists():
    df = pd.read_csv(feature_path)
    display(df.head())
    display(df.describe(include='all'))
else:
    print('feature table이 아직 없습니다. tools/leveling/build_feature_table.py를 먼저 실행하세요.')
